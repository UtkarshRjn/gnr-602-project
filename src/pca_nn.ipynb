# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import scipy.io as sio
import numpy as np
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
mat = sio.loadmat('/home/utkarsh/Documents/iitb/gnr602/project/dataset/Indian Pines/Indian_pines.mat')
mat_gt = sio.loadmat('/home/utkarsh/Documents/iitb/gnr602/project/dataset/Indian Pines/Indian_pines_gt.mat')

data = mat['indian_pines']
labels = mat_gt['indian_pines_gt']

# %%
# Reshape the data to (num_samples, num_features)
n, m, num_samples = data.shape
data_reshaped = np.reshape(data, (n*m, num_samples))
labels_reshaped = np.reshape(labels, (n*m,))

# Perform PCA to reduce the dimensionality of the data
num_components = 16
pca = PCA(n_components=num_components)
data_pca = pca.fit_transform(data_reshaped)

from keras.models import Sequential
from keras.layers import Dense, Conv1D

# Define the neural network architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=data_pca.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(17, activation='softmax'))

# Compile the model with categorical cross-entropy loss and Adam optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Convert labels to one-hot encoding
num_labels = len(np.unique(labels_reshaped))
labels_onehot = np.eye(num_labels)[labels_reshaped.reshape(-1)]

# print(labels_onehot)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data_pca, labels_onehot, test_size=0.3, random_state=42)

# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)
# Train the neural network on the training set
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the neural network on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", accuracy)
# Out:
# 2023-04-20 00:46:31.081667: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-20 00:46:31.278787: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-20 00:46:31.280163: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 00:46:32.568813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/50
# 368/368 [==============================] - 2s 4ms/step - loss: 89.6551 - accuracy: 0.4800 - val_loss: 25.9340 - val_accuracy: 0.5431
# Epoch 2/50
# 368/368 [==============================] - 2s 6ms/step - loss: 18.6711 - accuracy: 0.5722 - val_loss: 16.8632 - val_accuracy: 0.5560
# Epoch 3/50
# 368/368 [==============================] - 1s 3ms/step - loss: 14.3136 - accuracy: 0.5840 - val_loss: 13.2915 - val_accuracy: 0.5893
# Epoch 4/50
# 368/368 [==============================] - 1s 3ms/step - loss: 11.5477 - accuracy: 0.5983 - val_loss: 12.8384 - val_accuracy: 0.5921
# Epoch 5/50
# 368/368 [==============================] - 2s 4ms/step - loss: 9.3900 - accuracy: 0.6122 - val_loss: 12.3857 - val_accuracy: 0.5791
# Epoch 6/50
# 368/368 [==============================] - 2s 5ms/step - loss: 9.1408 - accuracy: 0.6043 - val_loss: 14.1421 - val_accuracy: 0.4976
# Epoch 7/50
# 368/368 [==============================] - 2s 5ms/step - loss: 7.9986 - accuracy: 0.6195 - val_loss: 8.6964 - val_accuracy: 0.5217
# Epoch 8/50
# 368/368 [==============================] - 2s 5ms/step - loss: 7.3074 - accuracy: 0.6196 - val_loss: 7.6674 - val_accuracy: 0.6070
# Epoch 9/50
# 368/368 [==============================] - 1s 2ms/step - loss: 6.5176 - accuracy: 0.6275 - val_loss: 7.0771 - val_accuracy: 0.6138
# Epoch 10/50
# 368/368 [==============================] - 1s 3ms/step - loss: 5.9686 - accuracy: 0.6296 - val_loss: 10.3672 - val_accuracy: 0.5350
# Epoch 11/50
# 368/368 [==============================] - 2s 5ms/step - loss: 5.3865 - accuracy: 0.6291 - val_loss: 4.3871 - val_accuracy: 0.6389
# Epoch 12/50
# 368/368 [==============================] - 1s 4ms/step - loss: 4.9263 - accuracy: 0.6346 - val_loss: 4.6201 - val_accuracy: 0.6365
# Epoch 13/50
# 368/368 [==============================] - 2s 5ms/step - loss: 4.2092 - accuracy: 0.6388 - val_loss: 4.9594 - val_accuracy: 0.5618
# Epoch 14/50
# 368/368 [==============================] - 2s 4ms/step - loss: 4.0880 - accuracy: 0.6330 - val_loss: 4.1859 - val_accuracy: 0.6253
# Epoch 15/50
# 368/368 [==============================] - 1s 3ms/step - loss: 3.3916 - accuracy: 0.6416 - val_loss: 3.2690 - val_accuracy: 0.6393
# Epoch 16/50
# 368/368 [==============================] - 2s 4ms/step - loss: 2.7509 - accuracy: 0.6470 - val_loss: 4.0433 - val_accuracy: 0.5414
# Epoch 17/50
# 368/368 [==============================] - 2s 4ms/step - loss: 2.5889 - accuracy: 0.6440 - val_loss: 2.8918 - val_accuracy: 0.6399
# Epoch 18/50
# 368/368 [==============================] - 1s 4ms/step - loss: 2.2998 - accuracy: 0.6399 - val_loss: 2.4824 - val_accuracy: 0.6328
# Epoch 19/50
# 368/368 [==============================] - 1s 3ms/step - loss: 2.1661 - accuracy: 0.6389 - val_loss: 2.5835 - val_accuracy: 0.6101
# Epoch 20/50
# 368/368 [==============================] - 1s 3ms/step - loss: 1.8469 - accuracy: 0.6557 - val_loss: 2.2771 - val_accuracy: 0.6243
# Epoch 21/50
# 368/368 [==============================] - 1s 4ms/step - loss: 1.6930 - accuracy: 0.6527 - val_loss: 1.7813 - val_accuracy: 0.6345
# Epoch 22/50
# 368/368 [==============================] - 1s 2ms/step - loss: 1.4980 - accuracy: 0.6543 - val_loss: 2.7717 - val_accuracy: 0.6128
# Epoch 23/50
# 368/368 [==============================] - 1s 4ms/step - loss: 1.4337 - accuracy: 0.6665 - val_loss: 1.3462 - val_accuracy: 0.6743
# Epoch 24/50
# 368/368 [==============================] - 1s 4ms/step - loss: 1.2310 - accuracy: 0.6726 - val_loss: 1.4051 - val_accuracy: 0.6624
# Epoch 25/50
# 368/368 [==============================] - 1s 2ms/step - loss: 1.2326 - accuracy: 0.6629 - val_loss: 1.1684 - val_accuracy: 0.6664
# Epoch 26/50
# 368/368 [==============================] - 2s 4ms/step - loss: 1.0734 - accuracy: 0.6726 - val_loss: 1.1822 - val_accuracy: 0.6739
# Epoch 27/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.9717 - accuracy: 0.6867 - val_loss: 1.0815 - val_accuracy: 0.6692
# Epoch 28/50
# 368/368 [==============================] - 1s 2ms/step - loss: 0.9733 - accuracy: 0.6891 - val_loss: 1.1569 - val_accuracy: 0.6712
# Epoch 29/50
# 368/368 [==============================] - 1s 2ms/step - loss: 0.8932 - accuracy: 0.6974 - val_loss: 1.1914 - val_accuracy: 0.6613
# Epoch 30/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.8826 - accuracy: 0.6959 - val_loss: 1.1437 - val_accuracy: 0.6773
# Epoch 31/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.8695 - accuracy: 0.7038 - val_loss: 0.9406 - val_accuracy: 0.6916
# Epoch 32/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.8555 - accuracy: 0.7001 - val_loss: 1.0189 - val_accuracy: 0.6950
# Epoch 33/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.8375 - accuracy: 0.7025 - val_loss: 0.9323 - val_accuracy: 0.6916
# Epoch 34/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.8161 - accuracy: 0.7098 - val_loss: 0.9527 - val_accuracy: 0.6940
# Epoch 35/50
# 368/368 [==============================] - 2s 5ms/step - loss: 0.7994 - accuracy: 0.7133 - val_loss: 0.8407 - val_accuracy: 0.7086
# Epoch 36/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.7936 - accuracy: 0.7135 - val_loss: 0.8820 - val_accuracy: 0.6946
# Epoch 37/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.7950 - accuracy: 0.7120 - val_loss: 0.8188 - val_accuracy: 0.7126
# Epoch 38/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.7979 - accuracy: 0.7099 - val_loss: 0.8638 - val_accuracy: 0.6844
# Epoch 39/50
# 368/368 [==============================] - 2s 5ms/step - loss: 0.7903 - accuracy: 0.7095 - val_loss: 0.9284 - val_accuracy: 0.6851
# Epoch 40/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.7857 - accuracy: 0.7119 - val_loss: 0.8171 - val_accuracy: 0.7157
# Epoch 41/50
# 368/368 [==============================] - 2s 5ms/step - loss: 0.7830 - accuracy: 0.7153 - val_loss: 0.9002 - val_accuracy: 0.6872
# Epoch 42/50
# 368/368 [==============================] - 2s 6ms/step - loss: 0.7850 - accuracy: 0.7208 - val_loss: 0.8526 - val_accuracy: 0.6895
# Epoch 43/50
# 368/368 [==============================] - 2s 4ms/step - loss: 0.7983 - accuracy: 0.7115 - val_loss: 0.9159 - val_accuracy: 0.6977
# Epoch 44/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.7983 - accuracy: 0.7159 - val_loss: 0.8640 - val_accuracy: 0.6933
# Epoch 45/50
# 368/368 [==============================] - 1s 4ms/step - loss: 0.7959 - accuracy: 0.7139 - val_loss: 0.8475 - val_accuracy: 0.6987
# Epoch 46/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.7802 - accuracy: 0.7205 - val_loss: 0.8383 - val_accuracy: 0.7001
# Epoch 47/50
# 368/368 [==============================] - 1s 3ms/step - loss: 0.7813 - accuracy: 0.7165 - val_loss: 0.8221 - val_accuracy: 0.7120
# Epoch 48/50
# 368/368 [==============================] - 1s 2ms/step - loss: 0.7752 - accuracy: 0.7217 - val_loss: 0.8397 - val_accuracy: 0.7194
# Epoch 49/50
# 368/368 [==============================] - 2s 5ms/step - loss: 0.7714 - accuracy: 0.7243 - val_loss: 0.9186 - val_accuracy: 0.6855
# Epoch 50/50
# 368/368 [==============================] - 2s 6ms/step - loss: 0.7578 - accuracy: 0.7251 - val_loss: 0.8093 - val_accuracy: 0.7167
# 198/198 [==============================] - 1s 2ms/step - loss: 0.7946 - accuracy: 0.7150
# Test accuracy: 0.7149651050567627

# %%
# Reshape the cluster labels and display the segmented image
cluster_labels_onehot = model.predict(data_pca)
# smoothed_preds = np.apply_along_axis(lambda x: np.convolve(x, [1/3, 1/3, 1/3], mode='same'), axis=1, arr=cluster_labels_onehot)
cluster_labels = np.argmax(cluster_labels_onehot, axis=1)

cluster_labels_reshaped = np.reshape(cluster_labels, (n, m))
accuracy = np.mean(cluster_labels_reshaped == labels)
print("Clustered labels accuracy:", accuracy)

plt.imshow(cluster_labels_reshaped)
plt.show()
# Out:
# 658/658 [==============================] - 1s 2ms/step
# Clustered labels accuracy: 0.7255172413793104

# %%
import cv2
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

sigmas = np.arange(0.01, 3.00, 0.01)  # different values of sigma to try
best_accuracy = 0
best_sigma = 0

# Reshape the cluster labels and display the segmented image
cluster_labels_onehot = model.predict(data_pca)
preds = np.reshape(cluster_labels_onehot, (n, m, 17))

for sigma in tqdm(sigmas):
    smoothed_preds = cv2.GaussianBlur(preds, (0, 0), sigma)

    cluster_labels_reshaped = np.argmax(smoothed_preds, axis=2)
    accuracy = np.mean(cluster_labels_reshaped == labels)

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_sigma = sigma
        best_image = cluster_labels_reshaped

print(f"Best sigma={best_sigma:.1f} with accuracy={best_accuracy:.4f}")

cluster_labels_flat = np.reshape(cluster_labels_reshaped, (n*m,))
mse = mean_squared_error(labels_reshaped, cluster_labels_flat)
print("MSE:", mse)
plt.imshow(best_image)
plt.show()
# Out:
# 658/658 [==============================] - 1s 2ms/step
# 100%|██████████| 299/299 [00:00<00:00, 305.44it/s]
# Best sigma=1.2 with accuracy=0.7727
# MSE: 25.69655172413793

# %%
plt.imshow(labels)
